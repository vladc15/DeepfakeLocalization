# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

iou_data = {
    
    "LDM": {
        
        "LDM": [32.04, 36.65, 37.41],
        "Repaint-P2-9k": [31.47, 32.07, 29.13],
        "LaMa": [23.67, 25.94, 25.83],
        "Pluralistic": [29.86, 30.75, 31.04],
        
    },
    "Repaint-P2-9k": {
        
        "LDM": [25.97, 26.14, 25.92],
        "Repaint-P2-9k": [50.03, 56.72, 59.34],
        "LaMa": [9.33, 5.53, 5.25],
        "Pluralistic": [17.7, 16.93, 18.41],
        
    },
    "LaMa": {
        
        "LDM": [6.33, 8.37, 5.1],
        "Repaint-P2-9k": [7.25, 9.81, 6.64],
        "LaMa": [60.46, 73.22, 77.79],
        "Pluralistic": [22.09, 26.83, 21.52],
        
    },
    "Pluralistic": {
        
        "LDM": [2.04, 1.15, 0.79],
        "Repaint-P2-9k": [2.71, 2.01, 1.55],
        "LaMa": [7.37, 7.55, 3.89],
        "Pluralistic": [69.19, 79.71, 79.94],
        
    },
    
}

conv_stages = ['conv-4', 'conv-12', 'conv-20']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(6, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - image_embed ({stage})')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
iou_data = {
    "LDM": {
        "LDM": [19.13, 26.22, 37.41],
        "Repaint-P2-9k": [17.15, 25.47, 29.13],
        "LaMa": [7.77, 14.39, 25.83],
        "Pluralistic": [12.35, 21.11, 31.04],
    },
    "Repaint-P2-9k": {
        "LDM": [23.21, 20.32, 25.92],
        "Repaint-P2-9k": [39.01, 57.32, 59.34],
        "LaMa": [6.01, 9.27, 5.25],
        "Pluralistic": [9.25, 19.72, 18.41],
    },
    "LaMa": {
        "LDM": [4.3, 6.18, 5.1],
        "Repaint-P2-9k": [3.12, 7.76, 6.64],
        "LaMa": [93.24, 93.54, 77.79],
        "Pluralistic": [27.65, 35.52, 21.52],
    },
    "Pluralistic": {
        "LDM": [0.52, 0.03, 0.79],
        "Repaint-P2-9k": [0.23, 0.1, 1.55],
        "LaMa": [20.64, 8.23, 3.89],
        "Pluralistic": [91.98, 92.02, 79.94],
    },
}

conv_stages = ['high_res_feats[0]', 'high_res_feats[1]', 'image_embed']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(6, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - SAM 2 {stage} (conv-20)')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
iou_data = {
    
    "LDM\nunseen": {
        "LDM": [9.48, 22.98],
        "Repaint-P2-9k": [25.08, 46.02],
        "LaMa": [86.78, 55.65],
        "Pluralistic": [74.71, 57.63],
    },
    "Repaint-P2-9k\nunseen": {
        "LDM": [21.72, 27.69],
        "Repaint-P2-9k": [2.65, 18.14],
        "LaMa": [87.55, 59.19],
        "Pluralistic": [77.71, 58.35],
    },
    "LaMa\nunseen": {
        "LDM": [22.91, 30.7],
        "Repaint-P2-9k": [31.14, 43.14],
        "LaMa": [7.52, 9.73],
        "Pluralistic": [63.17, 54.57],
    },
    "Pluralistic\nunseen": {
        "LDM": [26.44, 35.45],
        "Repaint-P2-9k": [39.86, 45.95],
        "LaMa": [86.14, 53.73],
        "Pluralistic": [24.04, 31.24],
    },
    
}

conv_stages = ['high_res_feats[1]', 'image_embed']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(6, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - SAM 2 {stage} (conv-20)')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

iou_data = {
    "LDM\nunseen": {
        "LDM": [28.86],
        "Repaint-P2-9k": [56.79],
        "LaMa": [62.13],
        "Pluralistic": [71.19],
    },
    "Repaint-P2-9k\nunseen": {
        "LDM": [42.55],
        "Repaint-P2-9k": [39.0],
        "LaMa": [60.29],
        "Pluralistic": [67.8],
    },
    "LaMa\nunseen": {
        "LDM": [41.03],
        "Repaint-P2-9k": [53.78],
        "LaMa": [39.61],
        "Pluralistic": [68.75],
    },
    "Pluralistic\nunseen": {
        "LDM": [42.95],
        "Repaint-P2-9k": [54.08],
        "LaMa": [57.17],
        "Pluralistic": [58.72],
    },
    "train_all_4": {
        "LDM": [41.92],
        "Repaint-P2-9k": [52.73],
        "LaMa": [57.7],
        "Pluralistic": [67.17],
    },
}




conv_stages = ['ViT']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(6, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - {stage} (conv-12)')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

iou_data = {
    "LDM\nunseen": {
        "LDM": [30.32],
        "Repaint-P2-9k": [57.29],
        "LaMa": [61.51],
        "Pluralistic": [68.97],
    },
    "Repaint-P2-9k\nunseen": {
        "LDM": [43.04],
        "Repaint-P2-9k": [40.42],
        "LaMa": [60.27],
        "Pluralistic": [67.37],
    },
    "LaMa\nunseen": {
        "LDM": [41.35],
        "Repaint-P2-9k": [53.57],
        "LaMa": [39.21],
        "Pluralistic": [66.71],
    },
    "Pluralistic\nunseen": {
        "LDM": [44.02],
        "Repaint-P2-9k": [52.92],
        "LaMa": [55.66],
        "Pluralistic": [54.58],
    },
    "train_all_4": {
        "LDM": [43.11],
        "Repaint-P2-9k": [55.33],
        "LaMa": [58.29],
        "Pluralistic": [67.24],
    },
}



conv_stages = ['ViT']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(6, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - {stage} (conv-20)')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

iou_data = {
    "train_all_4": {
        "LDM": [44.06],
        "Repaint-P2-9k": [62.44],
        "LaMa": [75.80],
        "Pluralistic": [72.67],
    },
}



conv_stages = ['ViT+RN50']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(3, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - {stage} (conv-12)')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

iou_data = {
    "LDM\nthird": {
        "LDM": [40.77],
        "Repaint-P2-9k": [37.92],
        "LaMa": [37.18],
        "Pluralistic": [49.66],
    },
    "Repaint-P2-9k\nthird": {
        "LDM": [26.61],
        "Repaint-P2-9k": [58.03],
        "LaMa": [24.84],
        "Pluralistic": [51.83],
    },
    "LaMa\nthird": {
        "LDM": [13.9],
        "Repaint-P2-9k": [21.49],
        "LaMa": [67.88],
        "Pluralistic": [51.02],
    },
    "Pluralistic\nthird": {
        "LDM": [6.66],
        "Repaint-P2-9k": [11.63],
        "LaMa": [13.21],
        "Pluralistic": [75.82],
    },
}




conv_stages = ['ViT']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(6, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - CLIP ViT')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

iou_data = {
    
    "LDM": {
        "LDM": [47.63],
        "Repaint-P2-9k": [43.71],
        "LaMa": [42.72],
        "Pluralistic": [55.41],
    },
    "Repaint-P2-9k": {
        "LDM": [31.04],
        "Repaint-P2-9k": [65.84],
        "LaMa": [33.34],
        "Pluralistic": [57.1],
    },
    "LaMa": {
        "LDM": [13.15],
        "Repaint-P2-9k": [20.69],
        "LaMa": [74.33],
        "Pluralistic": [53.65],
    },
    "Pluralistic": {
        "LDM": [8.85],
        "Repaint-P2-9k": [14.92],
        "LaMa": [19.01],
        "Pluralistic": [80.93],
    },  
}





conv_stages = ['ViT (conv-20)']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(6, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - CLIP {stage}')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

iou_data = {
    
    "LDM": {
        
        "LDM": [45.29],
        "Repaint-P2-9k": [36.0],
        "LaMa": [23.75],
        "Pluralistic": [35.46],
        
    },
    "Repaint-P2-9k": {
        
        "LDM": [23.86],
        "Repaint-P2-9k": [73.96],
        "LaMa": [42.13],
        "Pluralistic": [34.4],
        
    },
    "LaMa": {
        
        "LDM": [21.64],
        "Repaint-P2-9k": [33.16],
        "LaMa": [84.47],
        "Pluralistic": [40.28],
    },
    "Pluralistic": {
        "LDM": [12.81],
        "Repaint-P2-9k": [11.92],
        "LaMa": [61.53],
        "Pluralistic": [81.2],
        
    },
}



conv_stages = ['RN50 (conv-20)']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(6, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - CLIP {stage}')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

iou_data = {
    "LDM": {
        "LDM": [50.48],
        "Repaint-P2-9k": [46.17],
        "LaMa": [42.8],
        "Pluralistic": [55.03],
    },
    "Repaint-P2-9k": {
        "LDM": [23.81],
        "Repaint-P2-9k": [73.63],
        "LaMa": [37.51],
        "Pluralistic": [54.82],
    },
    "LaMa": {
        "LDM": [21.3],
        "Repaint-P2-9k": [29.63],
        "LaMa": [85.84],
        "Pluralistic": [30.98],
    },
    "Pluralistic": {
        "LDM": [4.05],
        "Repaint-P2-9k": [8.11],
        "LaMa": [51.66],
        "Pluralistic": [83.86],
    },
}




conv_stages = ['ViT+RN50 (conv-12)']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(6, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - CLIP {stage}')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import math

iou_data = {
    "LDM\nunseen": {
        "LDM": [30.86],
        "Repaint-P2-9k": [67.97],
        "LaMa": [78.88],
        "Pluralistic": [76.9],
    },
    "Repaint-P2-9k\nunseen": {
        "LDM": [44.08],
        "Repaint-P2-9k": [34.1],
        "LaMa": [76.91],
        "Pluralistic": [74.6],
    },
    "LaMa\nunseen": {
        "LDM": [45.75],
        "Repaint-P2-9k": [62.32],
        "LaMa": [61.61],
        "Pluralistic": [72.7],
    },
    "Pluralistic\nunseen": {
        "LDM": [43.51],
        "Repaint-P2-9k": [61.97],
        "LaMa": [75.91],
        "Pluralistic": [61.41],
    },
    "Train All 4": {
        "LDM": [44.06],
        "Repaint-P2-9k": [62.44],
        "LaMa": [75.80],
        "Pluralistic": [72.67],
    },
}


conv_stages = ['ViT+RN50 (conv-12)']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(8, 6))
    sns.set(font_scale=1.5)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores - {stage}')
    heatmap.set(xlabel='Train on', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import math

iou_data = {
    "ViT,RN50\nHard Voting": {
        "LDM": [39.02],
        "Repaint-P2-9k": [19.66],
        "LaMa": [35.76],
        "Pluralistic": [31.33],
    },
    "ViT,RN50\nSoft Voting": {
        "LDM": [44.16],
        "Repaint-P2-9k": [25.00],
        "LaMa": [41.27],
        "Pluralistic": [36.57],
    },
    "ViT,RN50,\nViT+RN50\nHard Voting": {
        "LDM": [49.12],
        "Repaint-P2-9k": [40.92],
        "LaMa": [52.96],
        "Pluralistic": [43.77],
    },
    "ViT,RN50,\nViT+RN50\nSoft Voting": {
        "LDM": [48.35],
        "Repaint-P2-9k": [39.65],
        "LaMa": [52.59],
        "Pluralistic": [41.11],
    },
    "ViT(pt),RN50,\nViT+RN50(pt)\nHard Voting": {
        "LDM": [51.32],
        "Repaint-P2-9k": [42.13],
        "LaMa": [56.87],
        "Pluralistic": [45.41],
    },
    "ViT(pt),RN50,\nViT+RN50(pt)\nSoft Voting": {
        "LDM": [51.15],
        "Repaint-P2-9k": [41.65],
        "LaMa": [57.05],
        "Pluralistic": [44.98],
    },
    "ViT+RN50(pt)": {
        "LDM": [51.03],
        "Repaint-P2-9k": [43.55],
        "LaMa": [56.46],
        "Pluralistic": [44.75],
    },
}


conv_stages = ['Voting Ensembles']

figs = []
for i, stage in enumerate(conv_stages):
    df = pd.DataFrame({train: {test: iou_data[train][test][i] for test in iou_data[train]} for train in iou_data})
    plt.figure(figsize=(11, 6))
    sns.set(font_scale=1.3)
    heatmap = sns.heatmap(df, annot=True, fmt='.1f', vmin=0, vmax=90, cmap="YlGnBu", cbar=False)
    heatmap.set_title(f'IOU Scores')
    heatmap.set(xlabel='Voting Ensembles / Models', ylabel='Test on')
    plt.tight_layout()
    figs.append(plt.gcf())
    plt.show()

# %%
import matplotlib.pyplot as plt

rounds = [i * 250 for i in range(13)]

iou_LDM = [30.86, 33.8, 35.11, 38.38, 39.09, 36.59, 37.67, 40.12, 37.36, 39.62, 40.47, 41.92, 42.36]
iou_Repaint = [67.97, 60.82, 61.31, 62.73, 60.89, 61.09, 58.77, 59.67, 58.65, 59.41, 58.64, 60.43, 61.72]
iou_LaMa = [78.88, 73.79, 73.94, 75.14, 72.23, 74.38, 74.24, 73.72, 72.75, 71.28, 71.94, 71.85, 74.74]
iou_Pluralistic = [76.9, 72.32, 73.9, 74.07, 72.72, 73.93, 74.22, 73.43, 71.71, 72.54, 73.16, 71.59, 73.91]

plt.figure(figsize=(10, 6))
sns.set(font_scale=1)
plt.plot(rounds, iou_LDM, marker='o', label='LDM')
plt.plot(rounds, iou_Repaint, marker='s', label='Repaint-P2-9k', linestyle='--')
plt.plot(rounds, iou_LaMa, marker='^', label='LaMa', linestyle='--')
plt.plot(rounds, iou_Pluralistic, marker='d', label='Pluralistic', linestyle='--')

plt.title('IOU Across Rounds of Adding Samples (finetuned on LDM)')
plt.xlabel('Samples Added')
plt.ylabel('Mean IOU (%)')
plt.xticks(rounds)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

rounds = [i * 250 for i in range(13)]

iou_LDM = [45.75, 29.3, 28.52, 29.09, 42.49, 41.97, 41.53, 42.88, 41.47, 41.75, 39.27, 40.57, 41.6]
iou_Repaint = [62.32, 65.93, 66.2, 64.32, 56.19, 55.39, 54.95, 55.97, 54.91, 56.6, 53.74, 55.86, 56.94]
iou_LaMa = [61.61, 79.06, 78.9, 78.59, 70.1, 69.94, 71.24, 70.85, 71.62, 72.23, 74.29, 72.73, 73.71]
iou_Pluralistic = [72.7, 76.99, 75.85, 75.88, 64.72, 64.31, 63.1, 65.39, 63.25, 63.19, 59.09, 64.01, 66.64]

plt.figure(figsize=(10, 6))
plt.plot(rounds, iou_LDM, marker='o', label='LDM', linestyle='--')
plt.plot(rounds, iou_Repaint, marker='s', label='Repaint-P2-9k', linestyle='--')
plt.plot(rounds, iou_LaMa, marker='^', label='LaMa')
plt.plot(rounds, iou_Pluralistic, marker='d', label='Pluralistic', linestyle='--')

plt.title('IOU Across Rounds of Adding Samples (finetuned on LaMa)')
plt.xlabel('Samples Added')
plt.ylabel('Mean IOU (%)')
plt.xticks(rounds)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

rounds = [i * 250 for i in range(13)]

iou_LDM = [43.51, 30.21, 30.02, 30.24, 21.04, 21.11, 25.29, 25.21, 21.13, 22.2, 20.35, 23.35, 25.58]
iou_Repaint = [61.97, 66.74, 65.1, 66.58, 44.41, 42.59, 46.76, 45.21, 42.69, 43.48, 40.46, 43.9, 46.15]
iou_LaMa = [75.91, 78.34, 77.63, 78.18, 69.18, 66.57, 68.43, 68.57, 69.75, 69.0, 65.55, 70.23, 70.3]
iou_Pluralistic = [61.41, 76.98, 77.3, 77.4, 71.08, 72.06, 72.0, 71.97, 73.55, 73.33, 73.29, 74.29, 74.03]

plt.figure(figsize=(10, 6))
plt.plot(rounds, iou_LDM, marker='o', label='LDM', linestyle='--')
plt.plot(rounds, iou_Repaint, marker='s', label='Repaint-P2-9k', linestyle='--')
plt.plot(rounds, iou_LaMa, marker='^', label='LaMa', linestyle='--')
plt.plot(rounds, iou_Pluralistic, marker='d', label='Pluralistic')

plt.title('IOU Across Rounds of Adding Samples (finetuned on Pluralistic)')
plt.xlabel('Samples Added')
plt.ylabel('Mean IOU (%)')
plt.xticks(rounds)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

rounds = [i * 250 for i in range(13)]

iou_LDM = [44.08, 30.67, 32.17, 42.51, 42.90, 41.17, 41.99, 41.71, 41.63, 39.56, 41.29, 39.65, 39.84]
iou_Repaint = [34.1, 67.74, 67.60, 55.59, 54.25, 58.24, 58.06, 58.29, 58.52, 59.47, 59.61, 60.92, 59.37]
iou_LaMa = [76.91, 77.68, 78.79, 75.55, 75.87, 74.86, 75.76, 76.36, 77.46, 76.47, 76.85, 76.56, 76.21]
iou_Pluralistic = [74.6, 74.44, 76.77, 68.50, 69.32, 65.17, 68.22, 69.48, 69.37, 66.03, 68.90, 67.25, 67.34]

plt.figure(figsize=(10, 6))
plt.plot(rounds, iou_LDM, marker='o', label='LDM', linestyle='--')
plt.plot(rounds, iou_Repaint, marker='s', label='Repaint-P2-9k')
plt.plot(rounds, iou_LaMa, marker='^', label='LaMa', linestyle='--')
plt.plot(rounds, iou_Pluralistic, marker='d', label='Pluralistic', linestyle='--')

plt.title('IOU Across Rounds of Adding Samples (finetuned on Repaint-P2-9k)')
plt.xlabel('Samples Added')
plt.ylabel('Mean IOU (%)')
plt.xticks(rounds)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
